# %%
class Dog:
  species='mammual'
  def __inti__(self,name,age):
    self.name=name
    self.age=age
def test():
  print("testing")
  print("over")

if __name__== "__main__" :
  test() 
# print("over")
# Out:
# testing
# over
